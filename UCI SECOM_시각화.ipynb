# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 시각화
Recall = np.array([73.1,76.1,66.6])
label = np.array(['XG Boost','Random Forest','Logistic'])
indices = np.argsort(Recall)
color = plt.cm.rainbow(np.linspace(0, 1, 9))

plt.rcParams['figure.figsize'] = (18, 7)
plt.bar(range(len(indices)), Recall[indices], color = color)
plt.xticks(range(len(indices)), label[indices])
plt.title('Recall Accuracy - Undersampled Data', fontsize = 30)
plt.grid()
plt.tight_layout()
plt.show()

# %%
# 시각화
Recall = np.array([66.6,77.7,85.7])
label = np.array(['Logistic','Random Forest','XG Boost - Grid Search'])
indices = np.argsort(Recall)
color = plt.cm.rainbow(np.linspace(0, 1, 9))

plt.rcParams['figure.figsize'] = (18, 7)
plt.bar(range(len(indices)), Recall[indices], color = color)
plt.xticks(range(len(indices)), label[indices])
plt.title('Recall Accuracy - OverSampled Data', fontsize = 30)
plt.grid()
plt.tight_layout()
plt.show()
